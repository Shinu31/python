# %%
import numpy as np
import pandas as pd

# %%
DF = pd.DataFrame({"Name":["Avery Bradley","John Holland","Jonas Jerebko","Jordan Mickey","Terry Rozier","Jared Sullinger","Evan Turner"],
                   "Team":['Boston Celtis' for i in range(0,7)],
                   "Number":[0.0,30.0,8.0,np.nan,12.0,7.0,11.0],
                   "Position":['PG','SG','PF','PF','PG','C','SG'],
                   "Age":[25.0,27.0,29.0,21.0,22.0,np.nan,27.0] })
DF
# Out:
#               Name           Team  Number Position   Age
# 0    Avery Bradley  Boston Celtis     0.0       PG  25.0
# 1     John Holland  Boston Celtis    30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtis     8.0       PF  29.0
# 3    Jordan Mickey  Boston Celtis     NaN       PF  21.0
# 4     Terry Rozier  Boston Celtis    12.0       PG  22.0
# 5  Jared Sullinger  Boston Celtis     7.0        C   NaN
# 6      Evan Turner  Boston Celtis    11.0       SG  27.0

# %%
DF.shape
# Out:
# (7, 5)

# %%
pd.DataFrame(DF,index=[4])
# Out:
#            Name           Team  Number Position   Age
# 4  Terry Rozier  Boston Celtis    12.0       PG  22.0

# %%
DF.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age'], dtype='object')

# %%
DF.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
DF.values
# Out:
# array([['Avery Bradley', 'Boston Celtis', 0.0, 'PG', 25.0],
#        ['John Holland', 'Boston Celtis', 30.0, 'SG', 27.0],
#        ['Jonas Jerebko', 'Boston Celtis', 8.0, 'PF', 29.0],
#        ['Jordan Mickey', 'Boston Celtis', nan, 'PF', 21.0],
#        ['Terry Rozier', 'Boston Celtis', 12.0, 'PG', 22.0],
#        ['Jared Sullinger', 'Boston Celtis', 7.0, 'C', nan],
#        ['Evan Turner', 'Boston Celtis', 11.0, 'SG', 27.0]], dtype=object)

# %%
DF.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# dtype: object

# %%
DF.size
# Out:
# 35

# %%
DF.shape[0] # number of rows
# Out:
# 7

# %%
len(DF)
# Out:
# 7

# %%
DF_2 = pd.DataFrame({
                     "Name":['Jack','Riti','Tom','Neelu','john','Mike'],
                     "Age":[34,30,31,32,16,17],
                     "City":['Sydeny','Delhi','Mumbai','Banglore','New York','las Vegas'],
                     "Country":['Australia','India','India','India','US','US'],
                     "Course":['Computer Science'for i in range(6)],
                     "Grade":['A' for i in range(6)]},index=['a','b','c','d','e','f'])
DF_2
# Out:
#     Name  Age       City    Country            Course Grade
# a   Jack   34     Sydeny  Australia  Computer Science     A
# b   Riti   30      Delhi      India  Computer Science     A
# c    Tom   31     Mumbai      India  Computer Science     A
# d  Neelu   32   Banglore      India  Computer Science     A
# e   john   16   New York         US  Computer Science     A
# f   Mike   17  las Vegas         US  Computer Science     A

# %%
DF_2['Age']
# Out:
# a    34
# b    30
# c    31
# d    32
# e    16
# f    17
# Name: Age, dtype: int64

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
DF_2.query('Age>30')
# Out:
#     Name  Age      City    Country            Course Grade
# a   Jack   34    Sydeny  Australia  Computer Science     A
# c    Tom   31    Mumbai      India  Computer Science     A
# d  Neelu   32  Banglore      India  Computer Science     A

# %%
DF_2.query('Country=="India"')
# Out:
#     Name  Age      City Country            Course Grade
# b   Riti   30     Delhi   India  Computer Science     A
# c    Tom   31    Mumbai   India  Computer Science     A
# d  Neelu   32  Banglore   India  Computer Science     A

# %%
DF_2[['Age']]
# Out:
#    Age
# a   34
# b   30
# c   31
# d   32
# e   16
# f   17

# %%
DF_2[DF_2.Name.str.endswith('i')]
# Out:
#    Name  Age   City Country            Course Grade
# b  Riti   30  Delhi   India  Computer Science     A

# %%
DF_2.iloc[0:3]
# Out:
#    Name  Age    City    Country            Course Grade
# a  Jack   34  Sydeny  Australia  Computer Science     A
# b  Riti   30   Delhi      India  Computer Science     A
# c   Tom   31  Mumbai      India  Computer Science     A

# %%
DF_2.flags
# Out:
# <Flags(allows_duplicate_labels=True)>

# %%
DF_2.ndim
# Out:
# 2

# %%
DF_2.empty
# Out:
# False

# %%
DF_2.compare
# Out:
# <bound method DataFrame.compare of     Name  Age       City    Country            Course Grade
# a   Jack   34     Sydeny  Australia  Computer Science     A
# b   Riti   30      Delhi      India  Computer Science     A
# c    Tom   31     Mumbai      India  Computer Science     A
# d  Neelu   32   Banglore      India  Computer Science     A
# e   john   16   New York         US  Computer Science     A
# f   Mike   17  las Vegas         US  Computer Science     A>

# %%
DF_2.head(2)
# Out:
#    Name  Age    City    Country            Course Grade
# a  Jack   34  Sydeny  Australia  Computer Science     A
# b  Riti   30   Delhi      India  Computer Science     A

# %%
DF_2.tail(2)
# Out:
#    Name  Age       City Country            Course Grade
# e  john   16   New York      US  Computer Science     A
# f  Mike   17  las Vegas      US  Computer Science     A

# %%
DF_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, a to f
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     6 non-null      object
#  1   Age      6 non-null      int64
#  2   City     6 non-null      object
#  3   Country  6 non-null      object
#  4   Course   6 non-null      object
#  5   Grade    6 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 508.0+ bytes
